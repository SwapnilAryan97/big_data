# %%
#import the necessary libraries

import numpy as np
import pandas as pd

import socket
import json

import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener

# %%
# Enter the tokens and keys for authorization. 
consumer_key = 'uxdbY8w9bTDG3hT6kQMGOhfd4'
consumer_secret = 'D0hVROObrCBS9Ef9Uf8qj2AA9868ItkF6n6tvFFCgiynftOMK7'
access_token = '2313751081-t5kxua4OLZcKOPuZuVrHO4FcyUyrteKUH3VOxLg'
access_secret = 'urzVDHXZqBtDBxg7e1cp31RFnSWssKZBYhafbtS8igcC3'

#OAuthHandler to authenticate with Twitter
authurization = tweepy.OAuthHandler(consumer_key, consumer_secret)
authurization.set_access_token(access_token, access_secret)
api = tweepy.API(auth)
#Finding all the tweets consist covid vaccine terms:
for tweet in api.search('covid vaccine'):
    print(tweet.text)
#define the columns in the dataframe
df = pd.DataFrame(columns = ['User', 'User_statuses_count', 'user_followers','fav_count','User_location','Tweets',])

#define a function to stream the data
def streaming(data, file_name):
    i = 0
    for tweet in tweepy.Cursor(api.search, q=data, count=100000, lang='en').items():
        print(i, end='\r')
        df.loc[i, 'User'] = tweet.user.name
        df.loc[i, 'User_statuses_count'] = tweet.user.statuses_count
        df.loc[i, 'user_followers'] = tweet.user.followers_count
        df.loc[i, 'fav_count'] = tweet.favorite_count
        df.loc[i, 'User_location'] = tweet.user.location
        df.loc[i, 'Tweets'] = tweet.text
        
#Write the output to a csv file     
        df.to_csv('{}.csv'.format(file_name))
        i+=1
        if i == 200:
            break
        else:
            pass

#Define streaming with any value of data. Here, we select joe biden
streaming(data = ['joe biden'], file_name = 'test_joebiden200')

# %%
df.head()
# Out:
#                    User User_statuses_count user_followers fav_count  \
# 0        sheila rodgers               86815            109         0
# 1               badbonz               77741           2247         0
# 2               Deb Max               40462            101         0
# 3               Nandini               71726            148         0
# 4  Roundtown Girl Again               19448           1327         0
#
#        User_location                                             Tweets
# 0                     RT @peterbakernyt: A majority of Americans in ...
# 1  south of clueless  RT @AdamParkhomenko: Donald Trump never even s...
# 2                     RT @davidmweissman: The way MSM is complaining...
# 3                     RT @Soumyadipta: President Joe Biden and VP Ka...
# 4                     Larry Kudlow: No! No! NOT PLANT BASED BEER! Jo...
